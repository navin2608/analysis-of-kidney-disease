# %%
import pandas as pd
#importing the dataset(.csv)file
df=pd.read_csv("Z:\ckdisease\kidney_disease.csv")
#displaying the contents for sample
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#        ...        pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0      ...         44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1      ...         38  6000  NaN   no   no   no  good   no   no            ckd
# 2      ...         31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3      ...         32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4      ...         35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#          ...        pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 395      ...         47  6700  4.9   no  no   no  good  no  no         notckd
# 396      ...         54  7800  6.2   no  no   no  good  no  no         notckd
# 397      ...         49  6600  5.4   no  no   no  good  no  no         notckd
# 398      ...         51  7200  5.9   no  no   no  good  no  no         notckd
# 399      ...         53  6800  6.1   no  no   no  good  no  no         notckd
#
# [5 rows x 26 columns]

# %%
df['id'].count()
# Out:
# 400

# %%
df['age'].value_counts()
# Out:
# 60.0    19
# 65.0    17
# 48.0    12
# 50.0    12
# 55.0    12
# 47.0    11
# 62.0    10
# 45.0    10
# 54.0    10
# 59.0    10
# 56.0    10
# 70.0     9
# 34.0     9
# 61.0     9
# 46.0     9
# 68.0     8
# 73.0     8
# 71.0     8
# 64.0     8
# 57.0     8
# 63.0     7
# 30.0     7
# 72.0     7
# 67.0     7
# 69.0     6
# 35.0     6
# 33.0     6
# 44.0     6
# 42.0     6
# 43.0     6
#         ..
# 32.0     3
# 17.0     3
# 25.0     3
# 8.0      3
# 29.0     3
# 21.0     2
# 5.0      2
# 49.0     2
# 15.0     2
# 28.0     2
# 12.0     2
# 20.0     2
# 36.0     2
# 19.0     2
# 82.0     1
# 7.0      1
# 2.0      1
# 78.0     1
# 90.0     1
# 3.0      1
# 6.0      1
# 11.0     1
# 4.0      1
# 83.0     1
# 27.0     1
# 14.0     1
# 81.0     1
# 22.0     1
# 26.0     1
# 79.0     1
# Name: age, Length: 76, dtype: int64

# %%
df['pc'].value_counts()
# Out:
# normal      259
# abnormal     76
# Name: pc, dtype: int64

# %%
df['ba'].value_counts()
# Out:
# notpresent    374
# present        22
# Name: ba, dtype: int64

# %%
df[df.hemo<10]
df
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5      5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6      6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present
# ...

# %%
a=df.iloc[:,1:3]
a.head()
# Out:
#     age    bp
# 0  48.0  80.0
# 1   7.0  50.0
# 2  62.0  80.0
# 3  48.0  70.0
# 4  51.0  80.0

# %%
a.describe()
# Out:
#               age          bp
# count  391.000000  388.000000
# mean    51.483376   76.469072
# std     17.169714   13.683637
# min      2.000000   50.000000
# 25%     42.000000   70.000000
# 50%     55.000000   80.000000
# 75%     64.500000   80.000000
# max     90.000000  180.000000

# %%
df['age'].min()
# Out:
# 2.0

# %%
df['age'].max()
# Out:
# 90.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
grouped=df.groupby(['age']).mean()
grouped
# Out:
#               id         bp        sg        al        su         bgr  \
# age
# 2.0   215.000000        NaN  1.010000  3.000000  0.000000         NaN
# 3.0   187.000000        NaN  1.010000  2.000000  0.000000         NaN
# 4.0   185.000000        NaN  1.020000  1.000000  0.000000   99.000000
# 5.0   103.000000  50.000000  1.012500  0.500000  0.000000         NaN
# 6.0   190.000000  60.000000  1.010000  4.000000  0.000000   94.000000
# 7.0     1.000000  50.000000  1.020000  4.000000  0.000000         NaN
# 8.0   174.666667  55.000000  1.022500  3.500000  0.000000   79.000000
# 11.0   47.000000  80.000000  1.010000  3.000000  0.000000         NaN
# 12.0  255.500000  70.000000  1.017500  1.500000  0.000000  100.000000
# 14.0  164.000000        NaN  1.015000  0.000000  0.000000  192.000000
# 15.0  224.500000  70.000000  1.022500  1.500000  0.000000   89.500000
# 17.0  224.333333  63.333333  1.016667  0.333333  0.000000   76.000000
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(15,5))
plt.plot(grouped['bgr'])
plt.title("Relation b/w Age & Blood glucose random")
plt.xlabel('age')
plt.ylabel('bgr')
plt.show()

# %%
df['su'].value_counts().plot(kind='bar',title='sugar level')
plt.ylabel('persons')
plt.xlabel('sugar level')
# Out:
# Text(0.5, 0, 'sugar level')

# %%
df['al'].value_counts().plot(kind='pie',title='almenia level')

# %%
df['pc'].value_counts().plot(kind='bar',title="range of pus cells")
plt.xlabel('classification')
plt.ylabel('persons')
# Out:
# Text(0, 0.5, 'persons')

# %%
df['pcc'].value_counts().plot(kind='bar',title='pus cell clumps')
plt.ylabel('persons')
# Out:
# Text(0, 0.5, 'persons')

# %%
df.plot(kind='scatter',x='su',y='bp',title="Relation b/w Sugar & Blood Pressure")

# %%
df.plot(kind='box',x='su',y='bp')
plt.title("box plot of sugar & bp")
plt.ylabel('su')
# Out:
# Text(0, 0.5, 'su')

# %%
pcc=df[df.pcc=='present']
pcc
# Out:
#       id   age     bp     sg   al   su       rbc        pc      pcc  \
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal  present
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal  present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal  present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal  present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal  present
# 12    12  68.0   70.0  1.015  3.0  1.0       NaN    normal  present
# 14    14  68.0   80.0  1.010  3.0  2.0    normal  abnormal  present
# 19    19  62.0   60.0  1.015  1.0  0.0       NaN  abnormal  present
# 29    29  68.0   70.0  1.005  1.0  0.0  abnormal  abnormal  present
# 31    31  73.0   90.0  1.015  3.0  0.0       NaN  abnormal  present
# 34    34  70.0   70.0  1.010  1.0  0.0    normal       NaN  present
# 49    49  60.0   70.0  1.010  2.0  0.0    normal  abnormal  present
# 51    51  54.0  100.0  1.015  3.0  0.0       NaN    normal  present
# ...

# %%
import numpy as np

# %%
grouped.head()
# Out:
#         id    bp      sg   al   su   bgr    bu    sc    sod  pot   hemo
# age
# 2.0  215.0   NaN  1.0100  3.0  0.0   NaN   NaN   NaN    NaN  NaN    NaN
# 3.0  187.0   NaN  1.0100  2.0  0.0   NaN  22.0  0.70    NaN  NaN  10.70
# 4.0  185.0   NaN  1.0200  1.0  0.0  99.0  23.0  0.60  138.0  4.4  12.00
# 5.0  103.0  50.0  1.0125  0.5  0.0   NaN  20.5  0.65  138.0  3.2   9.95
# 6.0  190.0  60.0  1.0100  4.0  0.0  94.0  67.0  1.00  135.0  4.9   9.90

# %%
plt.figure(figsize=(15,5))
plt.plot(grouped['bp'],color='g')
plt.xlabel("Age")
plt.ylabel("BP level")
plt.title("Relation b/w age & sugar level")

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(grouped['hemo'],color='r')
plt.xlabel("Age")
plt.ylabel("Hemoglobin level")
plt.title("Relation b/w age & hemoglobin")
plt.show()

# %%
grouped.describe()
# Out:
#                id         bp         sg         al         su         bgr  \
# count   76.000000  72.000000  73.000000  73.000000  73.000000   71.000000
# mean   207.126231  73.985557   1.017763   1.038725   0.388760  135.111764
# std     75.220537   8.364189   0.003799   0.974480   0.652296   39.065550
# min      1.000000  50.000000   1.010000   0.000000   0.000000   76.000000
# 25%    163.815789  70.000000   1.015000   0.250000   0.000000  103.683333
# 50%    204.000000  75.000000   1.017500   1.000000   0.000000  125.500000
# 75%    254.675000  80.000000   1.020000   1.500000   0.666667  161.437500
# max    374.000000  90.000000   1.025000   4.000000   4.000000  250.000000
#
#                bu         sc         sod        pot       hemo
# count   75.000000  75.000000   71.000000  71.000000  74.000000
# mean    50.819460   2.489711  137.646653   4.592311  12.802511
# std     23.555494   1.949411    5.005027   1.613757   1.880902
# ...

# %%
df[df['al']>=1]['age'].value_counts().sort_index().plot(kind='bar')

# %%
bins=[i*10 for i in range(0,11)]
df['AgeBin']=pd.cut(df['age'],bins)

# %%
df[df['al']>=1]['AgeBin'].value_counts().sort_index().plot(kind='bar')
plt.xlabel("Age(in years)")
plt.ylabel("Albium Level")
plt.title("relation b/w age and albium")
# Out:
# Text(0.5, 1.0, 'relation b/w age and albium')

# %%
df[pd.isnull(df['sod'])]
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 19    19  62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present
# 23    23  21.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 28    28  75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent
# 29    29  68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present
# 33    33  60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent
# ...

# %%
df['sod']=df['sod'].fillna(method='ffill')

# %%
sod=df['sod']

# %%
plt.plot(grouped['sod'])
plt.show()

# %%
grouped
# Out:
#               id         bp        sg        al        su         bgr  \
# age
# 2.0   215.000000        NaN  1.010000  3.000000  0.000000         NaN
# 3.0   187.000000        NaN  1.010000  2.000000  0.000000         NaN
# 4.0   185.000000        NaN  1.020000  1.000000  0.000000   99.000000
# 5.0   103.000000  50.000000  1.012500  0.500000  0.000000         NaN
# 6.0   190.000000  60.000000  1.010000  4.000000  0.000000   94.000000
# 7.0     1.000000  50.000000  1.020000  4.000000  0.000000         NaN
# 8.0   174.666667  55.000000  1.022500  3.500000  0.000000   79.000000
# 11.0   47.000000  80.000000  1.010000  3.000000  0.000000         NaN
# 12.0  255.500000  70.000000  1.017500  1.500000  0.000000  100.000000
# 14.0  164.000000        NaN  1.015000  0.000000  0.000000  192.000000
# 15.0  224.500000  70.000000  1.022500  1.500000  0.000000   89.500000
# 17.0  224.333333  63.333333  1.016667  0.333333  0.000000   76.000000
# ...

# %%
df.keys()
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification', 'AgeBin'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

x = [[df.age]]
y = [[df.hemo]]
plt.figure(figsize=(10,5))
plt.scatter(x, y)
plt.title("scatter plot ")
plt.xlabel("age")
plt.ylabel("hemoglobin level")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [[df.age]]
y = [[df.hemo]]
# plt.scatter(x, y)
# plt.show()

# convert list into array based on columns
data = np.column_stack((x, y))
data.reshape(-1,2)
# Out:
# array([[48. ,  7. ],
#        [62. , 48. ],
#        [51. , 60. ],
#        [68. , 24. ],
#        [52. , 53. ],
#        [50. , 63. ],
#        [68. , 68. ],
#        [68. , 40. ],
#        [47. , 47. ],
#        [60. , 62. ],
#        [61. , 60. ],
#        [48. , 21. ],
#        [42. , 61. ],
#        [75. , 69. ],
#        [75. , 68. ],
#        [ nan, 73. ],
#        [61. , 60. ],
#        [70. , 65. ],
#        [76. , 72. ],
#        [69. , 82. ],
#        [46. , 45. ],
#        [47. , 35. ],
#        [54. , 54. ],
#        [48. , 11. ],
#        [73. , 60. ],
#        [53. , 54. ],
#        [53. , 62. ],
#        [63. , 35. ],
#        [76. , 76. ],
#        [73. , 59. ],
#        [67. , 67. ],
#        [15. , 46. ],
#        [55. , 44. ],
#        [67. , 45. ],
#        [65. , 26. ],
#        [61. , 46. ],
#        [64. ,  nan],
#        [56. ,  5. ],
#        [48. , 67. ],
#        [70. , 56. ],
#        [74. , 45. ],
#        [38. , 48. ],
#        [59. , 70. ],
# ...
